# %%
3
# Out:
# 3

# %%
5
# Out:
# 5

# %%
3 + 5
# Out:
# 8

# %%
8 - 3
# Out:
# 5

# %%
_ # store previous value
# Out:
# 5

# %%
_ + 3
# Out:
# 8

# %%
_ * 2
# Out:
# 16

# %%
_ / 2
# Out:
# 8.0

# %%
14 / 2 #float division
# Out:
# 7.0

# %%
16 // 2  #int divsion
# Out:
# 8

# %%
4+5-10*3 #mas ( mul, add, sub)
# Out:
# -21

# %%
4+(5-10)*3  #bodmas
# Out:
# -11

# %%
4/(5-10)*3 #brack, div, mul, add, sub
# Out:
# -2.4000000000000004
