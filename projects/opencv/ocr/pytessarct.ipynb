# %%
import cv2
import imutils #We will need this library to resize our images.
import pytesseract #We will need this library to extract the license plate text from the detected license plate.

# %%
pytesseract.pytesseract.tesseract_cmd = r'D:\GIT_HUB\fullStackDatascience\projects\opencv\ocr'

# %%
image = cv2.imread(r'D:\GIT_HUB\fullStackDatascience\projects\opencv\ocr\car.jpg')
resized_image = imutils.resize(image)
cv2.imshow('original image', image)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 2
#       1 image = cv2.imread(r'D:\GIT_HUB\fullStackDatascience\projects\opencv\ocr\car.jpg')
# ----> 2 resized_image = imutils.resize(image)
#       3 cv2.imshow('original image', image)
#       4 cv2.waitKey(0)
#
# File c:\Python312\Lib\site-packages\imutils\convenience.py:69, in resize(image, width, height, inter)
#      65 def resize(image, width=None, height=None, inter=cv2.INTER_AREA):
#      66     # initialize the dimensions of the image to be resized and
#      67     # grab the image size
#      68     dim = None
# ---> 69     (h, w) = image.shape[:2]
#      71     # if both the width and height are None, then return the
#      72     # original image
#      73     if width is None and height is None:
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2.imshow("greyed image", gray_image)
cv2.waitKey(0)
# Out:
# 113

# %%
gray_image = cv2.bilateralFilter(gray_image, 11, 17, 17) 
cv2.imshow("smoothened image", gray_image)
cv2.waitKey(0)
# Out:
# 113

# %%
edged = cv2.Canny(gray_image, 30, 200) 
cv2.imshow("edged image", edged)
cv2.waitKey(0)
# Out:
# 113

# %%
cnts,new = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
image1=image.copy()
cv2.drawContours(image1,cnts,-1,(0,255,0),3)
cv2.imshow("contours",image1)
cv2.waitKey(0)
# Out:
# 113

# %%
cnts = sorted(cnts, key = cv2.contourArea, reverse = True) [:30]
screenCnt = None
image2 = image.copy()
cv2.drawContours(image2,cnts,-1,(0,255,0),3)
cv2.imshow("Top 30 contours",image2)
cv2.waitKey(0)
# Out:
# 113

# %%
i=7
for c in cnts:
        perimeter = cv2.arcLength(c, True)
        approx = cv2.approxPolyDP(c, 0.018 * perimeter, True)
        if len(approx) == 4: 
                screenCnt = approx
                x,y,w,h = cv2.boundingRect(c) 
                new_img=image[y:y+h,x:x+w]
                cv2.imwrite('./'+str(i)+'.png',new_img)
                i+=1
                break

# %%
cv2.drawContours(image, [screenCnt], -1, (0, 255, 0), 3)
cv2.imshow("image with detected license plate", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
