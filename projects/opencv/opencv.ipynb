# %%
# %pip install opencv-python
import cv2
import numpy as np
# Out:
# Collecting opencv-python
#   Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=2 in d:\GIT_HUB\.venv\Lib\site-packages (from opencv-python) (2.5.2)
# Using cached opencv_python-5.0.0.93-cp37-abi3-win_amd64.whl (44.0 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-5.0.0.93
# Note: you may need to restart the kernel to use updated packages.

# %%
input = cv2.imread(r'D:\GIT_HUB\FSDS_PROJECT\data\elephant.jfif')

# %%
input
# Out:
# array([[[210, 201, 187],
#         [208, 199, 185],
#         [206, 197, 183],
#         ...,
#         [211, 197, 178],
#         [211, 197, 178],
#         [211, 197, 178]],
#
#        [[216, 207, 193],
#         [214, 205, 191],
#         [211, 202, 188],
#         ...,
#         [211, 197, 178],
#         [211, 197, 178],
#         [211, 197, 178]],
#
#        [[224, 216, 203],
#         [222, 214, 201],
#         [217, 210, 195],
#         ...,
#         [211, 197, 178],
#         [211, 197, 178],
#         [211, 197, 178]],
#
#        ...,
#
#        [[122, 149, 186],
#         [116, 144, 179],
#         [114, 141, 178],
#         ...,
#         [118, 150, 193],
#         [109, 143, 186],
#         [121, 153, 196]],
#
#        [[120, 148, 183],
#         [116, 144, 179],
#         [114, 142, 177],
#         ...,
#         [114, 148, 191],
#         [107, 141, 184],
#         [117, 151, 194]],
#
#        [[117, 145, 180],
#         [116, 144, 179],
#         [115, 143, 178],
#         ...,
#         [110, 144, 187],
#         [104, 138, 181],
#         [114, 148, 191]]], shape=(275, 183, 3), dtype=uint8)

# %%
cv2.imshow('elephant', input)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print('Height of Image',int(input.shape[0]),'pixels')
print('width of Image',int(input.shape[1]),'pixels')
# Out:
# Height of Image 275 pixels
# width of Image 183 pixels

# %%
cv2.imwrite('output.png', input)
# Out:
# True

# %%
import os
os.getcwd()
# Out:
# 'd:\\GIT_HUB\\fullStackDatascience\\opencv'
